# %%
#Name: Fayez reg# 0032
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('jsrt_metadata.csv')

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
df['diagnosis']
# Out:
# 0             lung cancer
# 1      pulmonary hematoma
# 2             lung cancer
# 3       Inflammatory mass
# 4             lung cancer
#               ...
# 242                   NaN
# 243                   NaN
# 244                   NaN
# 245                   NaN
# 246                   NaN
# Name: diagnosis, Length: 247, dtype: object

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# lung cancer                                       56
# lung cancer(adenocarcinoma)                       23
# tuberculoma                                       14
# granuloma                                          8
# lung cancer(bronchioloalveolar cell carcinoma)     7
# unknown                                            4
# metastasis of colon cancer                         4
# inflammatory mass                                  4
# pulmonary tuberculosis                             3
# lung abscess                                       2
# Cryptococcosis                                     2
# lung cancer(squamous cell carcinoma)               2
# Inflammatory mass                                  2
# pulmonary hematoma                                 2
# susp. inflammatory mass                            2
# hamartoma                                          2
# sclerosing hemangioma                              2
# ...

# %%
df['state'].replace('non-nodule', np.nan, inplace=True)
# Out:
# C:\Users\l1f20bscs0032\AppData\Local\Temp\ipykernel_6824\2181178566.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['state'].replace('non-nodule', np.nan, inplace=True)

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety     93
# size         93
# age           0
# gender        0
# x            93
# y            93
# state        93
# position     93
# diagnosis    93
# dtype: int64

# %%
val = int(df['subtlety'].astype('float').mean())

# %%
val
# Out:
# 2

# %%
df['subtlety'].replace(np.nan, val, inplace=True)
# Out:
# C:\Users\l1f20bscs0032\AppData\Local\Temp\ipykernel_6824\1115661853.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['subtlety'].replace(np.nan, val, inplace=True)

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety      0
# size         93
# age           0
# gender        0
# x            93
# y            93
# state        93
# position     93
# diagnosis    93
# dtype: int64

# %%
val = int(df['size'].astype('float').mean())

# %%
val
# Out:
# 17

# %%
df['size'].replace(np.nan, val, inplace=True)
# Out:
# C:\Users\l1f20bscs0032\AppData\Local\Temp\ipykernel_6824\2060766045.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['size'].replace(np.nan, val, inplace=True)

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety      0
# size          0
# age           0
# gender        0
# x            93
# y            93
# state        93
# position     93
# diagnosis    93
# dtype: int64

# %%
val = int(df['x'].astype('float').mean())

# %%
val
# Out:
# 937

# %%
df['x'].replace(np.nan, val, inplace=True)
# Out:
# C:\Users\l1f20bscs0032\AppData\Local\Temp\ipykernel_6824\1622397262.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['x'].replace(np.nan, val, inplace=True)

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety      0
# size          0
# age           0
# gender        0
# x             0
# y            93
# state        93
# position     93
# diagnosis    93
# dtype: int64

# %%
val = int(df['y'].astype('float').mean())

# %%
val
# Out:
# 868

# %%
df['y'].replace(np.nan, val, inplace=True)
# Out:
# C:\Users\l1f20bscs0032\AppData\Local\Temp\ipykernel_6824\4264142210.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['y'].replace(np.nan, val, inplace=True)

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety      0
# size          0
# age           0
# gender        0
# x             0
# y             0
# state        93
# position     93
# diagnosis    93
# dtype: int64

# %%
val = df['state'].value_counts().idxmax()

# %%
val
# Out:
# 'malignant'

# %%
df['state'].replace(np.nan, val, inplace=True)
# Out:
# C:\Users\l1f20bscs0032\AppData\Local\Temp\ipykernel_6824\2295548925.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['state'].replace(np.nan, val, inplace=True)

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety      0
# size          0
# age           0
# gender        0
# x             0
# y             0
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
val = df['position'].value_counts().idxmax()

# %%
val
# Out:
# 'r.upper lobe(S2)'

# %%
df['position'].replace(np.nan, val, inplace=True)
# Out:
# C:\Users\l1f20bscs0032\AppData\Local\Temp\ipykernel_6824\1848827389.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['position'].replace(np.nan, val, inplace=True)

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety      0
# size          0
# age           0
# gender        0
# x             0
# y             0
# state         0
# position      0
# diagnosis    93
# dtype: int64

# %%
val = df['diagnosis'].value_counts().idxmax()

# %%
val
# Out:
# 'lung cancer'

# %%
df['diagnosis'].replace(np.nan, val, inplace=True)

# %%
df.isnull().sum()
# Out:
# study_id     0
# subtlety     0
# size         0
# age          0
# gender       0
# x            0
# y            0
# state        0
# position     0
# diagnosis    0
# dtype: int64

# %%
counts = df['diagnosis'].value_counts()

# %%
mylabels = df['diagnosis'].value_counts().keys()

# %%
counts
# Out:
# diagnosis
# lung cancer                                       149
# lung cancer(adenocarcinoma)                        23
# tuberculoma                                        14
# granuloma                                           8
# lung cancer(bronchioloalveolar cell carcinoma)      7
# unknown                                             4
# metastasis of colon cancer                          4
# inflammatory mass                                   4
# pulmonary tuberculosis                              3
# lung abscess                                        2
# Cryptococcosis                                      2
# lung cancer(squamous cell carcinoma)                2
# Inflammatory mass                                   2
# pulmonary hematoma                                  2
# susp. inflammatory mass                             2
# hamartoma                                           2
# sclerosing hemangioma                               2
# ...

# %%
mylabels
# Out:
# Index(['lung cancer', 'lung cancer(adenocarcinoma)', 'tuberculoma',
#        'granuloma', 'lung cancer(bronchioloalveolar cell carcinoma)',
#        'unknown', 'metastasis of colon cancer', 'inflammatory mass',
#        'pulmonary tuberculosis', 'lung abscess', 'Cryptococcosis',
#        'lung cancer(squamous cell carcinoma)', 'Inflammatory mass',
#        'pulmonary hematoma', 'susp. inflammatory mass', 'hamartoma',
#        'sclerosing hemangioma', 'lung cancer(large cell carcinoma)',
#        'susp. hamartoma', 'metastasis of uterine cancer',
#        'organizing pneumonia', 'metastasis of ovarian cancer',
#        'metastatic lung cancer', 'lung canceror metastasis', 'pneumonia',
#        'calcified granuloma', 'lung cancer(adenosquamous carcinoma)',
#        'lung cancer(small cell carcinoma)', 'susp.tuberculoma',
#        'organiging pneumonia', 'susp. sclerosing hemangioma',
#        'susp. lung metastasis'],
#       dtype='object', name='diagnosis')

# %%
plt.hist(df['diagnosis'].value_counts())
# Out:
# (array([30.,  1.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([  1. ,  15.8,  30.6,  45.4,  60.2,  75. ,  89.8, 104.6, 119.4,
#         134.2, 149. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(mylabels, counts)
plt.title('Total Number of Patients of each Disease')
plt.ylabel('Number of Patients')
plt.xlabel('Diseases')
plt.xticks(rotation='vertical')
plt.show()

# %%
counts = df[['diagnosis','state']].value_counts()

# %%
mylabels = df[['diagnosis','state']].value_counts().keys()

# %%
counts
# Out:
# diagnosis                                       state
# lung cancer                                     malignant    149
# lung cancer(adenocarcinoma)                     malignant     23
# tuberculoma                                     benign        14
# granuloma                                       benign         8
# lung cancer(bronchioloalveolar cell carcinoma)  malignant      7
# unknown                                         benign         4
# metastasis of colon cancer                      malignant      4
# inflammatory mass                               benign         4
# pulmonary tuberculosis                          benign         3
# susp. inflammatory mass                         benign         2
# sclerosing hemangioma                           benign         2
# pulmonary hematoma                              benign         2
# Inflammatory mass                               benign         2
# Cryptococcosis                                  benign         2
# ...

# %%
mylabels
# Out:
# MultiIndex([(                                   'lung cancer', 'malignant'),
#             (                   'lung cancer(adenocarcinoma)', 'malignant'),
#             (                                   'tuberculoma',    'benign'),
#             (                                     'granuloma',    'benign'),
#             ('lung cancer(bronchioloalveolar cell carcinoma)', 'malignant'),
#             (                                       'unknown',    'benign'),
#             (                    'metastasis of colon cancer', 'malignant'),
#             (                             'inflammatory mass',    'benign'),
#             (                        'pulmonary tuberculosis',    'benign'),
#             (                       'susp. inflammatory mass',    'benign'),
#             (                         'sclerosing hemangioma',    'benign'),
#             (                            'pulmonary hematoma',    'benign'),
# ...

# %%
plt.pie(counts,radius=6,startangle=-25,autopct='%1.1f%%',shadow=True)
plt.legend(loc='center left',labels = mylabels, fontsize = 15, bbox_to_anchor=(1, 2))
plt.show()

# %%
counts = df[['diagnosis','gender']].value_counts()

# %%
mylabels = df[['diagnosis','gender']].value_counts().keys()

# %%
plt.pie(counts, radius=6,autopct='%1.1f%%',shadow=True)
plt.legend(loc='upper left',labels = mylabels, fontsize = 15,bbox_to_anchor=(2,3.5))
plt.show()
